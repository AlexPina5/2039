# %% [markdown]
# # Welcome to an example Binder

# %% [markdown]
# We need `seaborn`, which shall be included it in `requirements.txt` file

# %%
# %ls
# Out:
#  00_00_binder.ipynb                     data.csv
#  00_00_primer_pasos.ipynb               headbrain.csv
#  01_01_data_types.ipynb                 movies.csv
#  01_02_read_iloc_unique_groupby.ipynb   nhanes_2015_2016.csv
#  01_03_data_wrangling.ipynb             pokemon.csv
#  adult.csv                              README.md
#  airline_data.csv                       _read_me.txt
#  antropometria00.csv                   'requirements copy.txt'
#  antropometria-dataset.csv              requirements.txt
#  Canada.xlsx                            sample_pivot.csv
#  Cartwheeldata.csv                      tips.csv
#  census.csv                             weight-height.csv
#  cwurData.csv

# %%
import numpy as np

# %%
import matplotlib.pylot as plt

n=100
np.random.rand(n)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-3-170c95c97f4d> in <module>
# ----> 1 import matplotlib.pylot as plt
#       2
#       3 n=100
#       4 np.random.rand(n)
#
# ModuleNotFoundError: No module named 'matplotlib.pylot'

# %%
type(x)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-191ea9c3d109> in <module>
# ----> 1 type(x)
#
# NameError: name 'x' is not defined

# %%
import math

# %%
type(4)
# Out:
# int

# %%
type(4.0)
# Out:
# float

# %%
numeros=[2,3,4,5]

# %%
numeros
# Out:
# [2, 3, 4, 5]

# %%
type(numeros)
# Out:
# list

# %%
suma = sum(numeros)

# %%
suma
# Out:
# 14

# %%
promedio = suma/len(numeros)
promedio
# Out:
# 3.5

# %%
len(numeros)
# Out:
# 4

# %%
6*10**2
# Out:
# 600

# %%
print (math.pi)
# Out:
# 3.141592653589793

# %%
type(math.pi)
# Out:
# float

# %%
lista_mezcla = [math.pi, 3/5, 4.1, 3]
print(lista_mezcla)
# Out:
# [3.141592653589793, 0.6, 4.1, 3]

# %%
promedio = sum(lista_mezcla)/len(lista_mezcla)

# %%
promedio
# Out:
# 2.710398163397448

# %%
type(True)
# Out:
# bool

# %%
type(name)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-26-8584777fc013> in <module>
# ----> 1 type(name)
#
# NameError: name 'name' is not defined

# %%
x = 6 
y = 7
if x<y:
    print('() es menor que {}'.format (x,y))
else:
    print('() es menor que {}'.format (y,x))
# Out:
# () es menor que 6

# %%
str_list = ['dog', 'koala', 'goose']
str_list
# Out:
# ['dog', 'koala', 'goose']

# %%
len(str_list)
# Out:
# 3

# %%
type(None)
# Out:
# NoneType

# %%
none_list = [None]*5
none_list
# Out:
# [None, None, None, None, None]

# %%
len(none_list)
# Out:
# 5

# %%
otra_list = [1, 1.1, 'a_str', None]
for i in otra_list:
    print('{} {}'.format(i, type(i)))
# Out:
# 1 <class 'int'>
# 1.1 <class 'float'>
# a_str <class 'str'>
# None <class 'NoneType'>

# %%
a_list = ['third', 'fisrt', 'medium', 'small', 'large']
a_list
# Out:
# ['third', 'fisrt', 'medium', 'small', 'large']

# %%
type(a_list)
# Out:
# list

# %%
a_list[1]
# Out:
# 'fisrt'
